# %% [markdown]
# <a href="https://colab.research.google.com/github/sudo-lofi/AnaliseExploratoria/blob/main/notebooks_Projeto_Ciencia_de_dados'_Dataset_LimpezaDeDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# Primeiro, devemos importar as bibliotecas que serão utilizadas

# %%
import pandas as pd

# %matplotlib inline

# %%
filmes_csv = 'Dataset/movies.csv'
ratings_csv = 'Dataset/ratings.csv'



filmes_df = pd.read_csv(filmes_csv)
ratings_df = pd.read_csv(ratings_csv)

# %%
filmes_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20549 entries, 0 to 20548
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  20549 non-null  int64
#  1   title    20549 non-null  object
#  2   genres   20549 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 481.7+ KB

# %% [markdown]
# ## Vamos renomear o nome das colunas para ficar mais entendivel

# %%
filmes_df.rename(columns={'e (2016)': 'Nome', 'Crime|Drama': 'Genero'}).head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## Juntando o dataset de filmes com dataset de notas

# %%
df = filmes_df.merge(ratings_df,on=["movieId"])
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating     timestamp
# 0       4     4.0  1.113766e+09
# 1      10     5.0  9.488858e+08
# 2      14     4.5  1.442169e+09
# 3      15     4.0  1.370810e+09
# 4      22     4.0  1.237623e+09

# %% [markdown]
# ## Renomeando as colunas do novo dataset conjunto

# %%
df = df.rename(columns={'movieId':'Filme ID','title': 'Nome', 'genres': 'Genero', 'userId': 'ID Usuário', 'rating': 'Nota'})

df
# Out:
#        Filme ID                     Nome  \
# 0             1         Toy Story (1995)
# 1             1         Toy Story (1995)
# 2             1         Toy Story (1995)
# 3             1         Toy Story (1995)
# 4             1         Toy Story (1995)
# ...         ...                      ...
# 40468     99917    Upstream Color (2013)
# 40469     99917    Upstream Color (2013)
# 40470     99941  Double Indemnity (1973)
# 40471     99957       Broken City (2013)
# 40472     99992     Shadow Dancer (2012)
#
#                                             Genero  ID Usuário  Nota  \
# 0      Adventure|Animation|Children|Comedy|Fantasy           4   4.0
# 1      Adventure|Animation|Children|Comedy|Fantasy          10   5.0
# 2      Adventure|Animation|Children|Comedy|Fantasy          14   4.5
# 3      Adventure|Animation|Children|Comedy|Fantasy          15   4.0
# 4      Adventure|Animation|Children|Comedy|Fantasy          22   4.0
# ...                                            ...         ...   ...
# 40468                      Romance|Sci-Fi|Thriller          48   4.5
# 40469                      Romance|Sci-Fi|Thriller         248   0.5
# 40470                         Crime|Drama|Thriller         277   3.5
# 40471                         Crime|Drama|Thriller         214   2.0
# 40472                         Crime|Drama|Thriller         214   4.0
#
#           timestamp
# 0      1.113766e+09
# 1      9.488858e+08
# 2      1.442169e+09
# 3      1.370810e+09
# 4      1.237623e+09
# ...             ...
# 40468  1.527522e+09
# 40469  1.511188e+09
# 40470  1.428191e+09
# 40471  1.371394e+09
# 40472  1.422230e+09
#
# [40473 rows x 6 columns]

# %% [markdown]
# ## Procurando por linhas com valores nulos

# %%
df.isnull().sum()
# Out:
# Filme ID      0
# Nome          0
# Genero        0
# ID Usuário    0
# Nota          0
# timestamp     0
# dtype: int64

# %% [markdown]
# ## Removendo linhas com valores nulos
# Por meio de analize observamos que a coluna as notas possue um valor nulo, portanto, iremos remove-lo.

# %%
df.dropna(subset=['Nota'], inplace=True)

# %%
df['Genero'].to_csv('Dataset/genero.csv', index=False)

# %%
genero_df = pd.read_csv('Dataset/genero.csv')
genero_df['Genero'] = genero_df['Genero'].str.lower().str.split("|")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-c3bc83f04d81> in <module>
#       1 genero_df = pd.read_csv('Dataset/genero.csv')
#       2 genero_df['Genero'] = genero_df['Genero'].str.lower().str.split("|")
# ----> 3 pd.Series({Genero: genero_df['Genero'].unique() for Genero in genero_df })
#
# <ipython-input-41-c3bc83f04d81> in <dictcomp>(.0)
#       1 genero_df = pd.read_csv('Dataset/genero.csv')
#       2 genero_df['Genero'] = genero_df['Genero'].str.lower().str.split("|")
# ----> 3 pd.Series({Genero: genero_df['Genero'].unique() for Genero in genero_df })
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in unique(self)
#    2037         Categories (3, object): ['a' < 'b' < 'c']
#    2038         """
# -> 2039         return super().unique()
#    2040
#    2041     @overload
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/base.py in unique(self)
#     977                     result = np.asarray(result)
#     978         else:
# --> 979             result = unique1d(values)
#     980
#     981         return result
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in unique(values)
#     429
#     430     table = htable(len(values))
# --> 431     uniques = table.unique(values)
#     432     uniques = _reconstruct_data(uniques, original.dtype, original)
#     433     return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
